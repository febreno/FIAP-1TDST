# %% [markdown]
# **INTEGRANTES CHALLANGE IBM**
#
# **NOMES:**
#
# Felipe Breno Sugisawa Altran - RM 94170 </br>
# Leandro Alves de Souza Braga - RM 94513 </br>
# Leonardo Lima Barbosa - RM 95432 </br>
# Rafaela Gomes da Silva - RM 94972 </br>
# Vinicius Alves Torres - RM 94266 </br>
#
# **Análise Exploratória**

# %%
# BIBLIOTECAS
# análise e manipulação de dados
import pandas as pd
# plotagem de gráficos estatísticos
import seaborn as sns
# visualização de dados em Python em diferentes graficos
import matplotlib.pyplot as plt

# %%
# Armazenandos os dados em um DataFrame
# dados = pd.read_csv("dados_rh.csv", sep = ',') 

#-------------------------------------------------------------------------------#
# https://drive.google.com/file/d/19yBRjIOf3n7aoTOzi1une26m7ooTjNaw/view?usp=sharing
from google_drive_downloader import GoogleDriveDownloader as gdd

data_google_id = '19yBRjIOf3n7aoTOzi1une26m7ooTjNaw'
gdd.download_file_from_google_drive(file_id=data_google_id, 
                                    dest_path = './dados_rh.csv', 
                                    showsize = True)# (link hash, save here as, view download)

dados = pd.read_csv("dados_rh.csv", sep = ',')

# %% [markdown]
# # Nova seção

# %%
# Colunas e Linhas
dados[["id_empregado","educacao","departamento","genero","canal_de_recrutamento","n_de_treinamentos","idade","pontuacao_ano_anterior","tempo_de_servico","KPIs >80%","venceu_premiacoes?","pontuacao_media_treinamentos","foi_promovido"]]
# Out:
#        id_empregado          educacao        departamento genero  \
# 0             65438  Mestrado & acima  Vendas & Marketing      F
# 1             65141       Bacharelado           Operacoes      M
# 2              7513       Bacharelado  Vendas & Marketing      M
# 3              2542       Bacharelado  Vendas & Marketing      M
# 4             48945       Bacharelado          Tecnologia      M
# ...             ...               ...                 ...    ...
# 54803          3030       Bacharelado          Tecnologia      M
# 54804         74592  Mestrado & acima           Operacoes      F
# 54805         13918       Bacharelado             Analise      M
# 54806         13614               NaN  Vendas & Marketing      M
# 54807         51526       Bacharelado                  RH      M
#
#       canal_de_recrutamento  n_de_treinamentos  idade  pontuacao_ano_anterior  \
# 0         processo seletivo                  1     35                     5.0
# ...

# %%
# Tipos de dados
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54808 entries, 0 to 54807
# Data columns (total 14 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   id_empregado                  54808 non-null  int64
#  1   departamento                  54808 non-null  object
#  2   regiao                        54808 non-null  object
#  3   educacao                      52399 non-null  object
#  4   genero                        54808 non-null  object
#  5   canal_de_recrutamento         54808 non-null  object
#  6   n_de_treinamentos             54808 non-null  int64
#  7   idade                         54808 non-null  int64
#  8   pontuacao_ano_anterior        50684 non-null  float64
#  9   tempo_de_servico              54808 non-null  int64
#  10  KPIs >80%                     54808 non-null  int64
#  11  venceu_premiacoes?            54808 non-null  int64
# ...

# %%
# Visualizando as 5 primeiras linha
dados.head()
# Out:
#    id_empregado        departamento     regiao          educacao genero  \
# 0         65438  Vendas & Marketing   regiao_7  Mestrado & acima      F
# 1         65141           Operacoes  regiao_22       Bacharelado      M
# 2          7513  Vendas & Marketing  regiao_19       Bacharelado      M
# 3          2542  Vendas & Marketing  regiao_23       Bacharelado      M
# 4         48945          Tecnologia  regiao_26       Bacharelado      M
#
#   canal_de_recrutamento  n_de_treinamentos  idade  pontuacao_ano_anterior  \
# 0     processo seletivo                  1     35                     5.0
# 1                outros                  1     30                     5.0
# 2     processo seletivo                  1     34                     3.0
# 3                outros                  2     39                     1.0
# 4                outros                  1     45                     3.0
#
#    tempo_de_servico  KPIs >80%  venceu_premiacoes?  \
# ...

# %%
# Últimas linhas
dados.tail()
# Out:
#        id_empregado        departamento     regiao          educacao genero  \
# 54803          3030          Tecnologia  regiao_14       Bacharelado      M
# 54804         74592           Operacoes  regiao_27  Mestrado & acima      F
# 54805         13918             Analise   regiao_1       Bacharelado      M
# 54806         13614  Vendas & Marketing   regiao_9               NaN      M
# 54807         51526                  RH  regiao_22       Bacharelado      M
#
#       canal_de_recrutamento  n_de_treinamentos  idade  pontuacao_ano_anterior  \
# 54803     processo seletivo                  1     48                     3.0
# 54804                outros                  1     37                     2.0
# 54805                outros                  1     27                     5.0
# 54806     processo seletivo                  1     29                     1.0
# 54807                outros                  1     27                     1.0
#
# ...

# %%
dados_1 = pd.get_dummies(dados["foi_promovido"], prefix = "Aprovados")
dados_1.head()
# Out:
#    Aprovados_0  Aprovados_1
# 0            1            0
# 1            1            0
# 2            1            0
# 3            1            0
# 4            1            0

# %%
# Tamanho dos dados
dados.shape
# Out:
# (54808, 14)

# %%
# Tipos de dados 
dados.dtypes
# Out:
# id_empregado                      int64
# departamento                     object
# regiao                           object
# educacao                         object
# genero                           object
# canal_de_recrutamento            object
# n_de_treinamentos                 int64
# idade                             int64
# pontuacao_ano_anterior          float64
# tempo_de_servico                  int64
# KPIs >80%                         int64
# venceu_premiacoes?                int64
# pontuacao_media_treinamentos      int64
# foi_promovido                     int64
# dtype: object

# %%
# Filtrando dados
dados.idade
# Out:
# 0        35
# 1        30
# 2        34
# 3        39
# 4        45
#          ..
# 54803    48
# 54804    37
# 54805    27
# 54806    29
# 54807    27
# Name: idade, Length: 54808, dtype: int64

# %%
# Dados com valor percentual x100
percentual4 = dados['regiao'].value_counts(normalize = True) * 100
percentual4
# Out:
# regiao_2     22.520435
# regiao_22    11.728215
# regiao_7      8.836301
# regiao_15     5.123340
# regiao_13     4.831411
# regiao_26     4.123486
# regiao_31     3.530506
# regiao_4      3.107211
# regiao_27     3.026930
# regiao_16     2.672967
# regiao_28     2.404758
# regiao_11     2.399285
# regiao_23     2.143848
# regiao_29     1.813604
# regiao_32     1.724201
# regiao_19     1.594658
# regiao_20     1.550868
# regiao_14     1.508904
# regiao_25     1.494307
# regiao_17     1.452343
# regiao_5      1.397606
# regiao_6      1.258940
# regiao_30     1.198730
# regiao_8      1.195081
# regiao_10     1.182309
# regiao_1      1.112976
# regiao_24     0.926872
# regiao_12     0.912276
# regiao_9      0.766311
# regiao_21     0.749891
# regiao_3      0.631295
# regiao_34     0.532769
# regiao_33     0.490804
# regiao_18     0.056561
# Name: regiao, dtype: float64

# %%
# Selecionando apenas uma coluna
dados["id_empregado"]
# Out:
# 0        65438
# 1        65141
# 2         7513
# 3         2542
# 4        48945
#          ...
# 54803     3030
# 54804    74592
# 54805    13918
# 54806    13614
# 54807    51526
# Name: id_empregado, Length: 54808, dtype: int64

# %%
# Filtrando pelos números de linhas e colunas
# linha 0, coluna 1
dados.iloc[0, 1]
# Out:
# 'Vendas & Marketing'

# %%
# Selecionando linhas e colunas especificas
dados.iloc[[2,5], [3,4]]
# Out:
#       educacao genero
# 2  Bacharelado      M
# 5  Bacharelado      M

# %%
# Selecionando um intervalo de linhas e duas colunas
dados.iloc[0:10, [1,5]]
# Out:
#          departamento canal_de_recrutamento
# 0  Vendas & Marketing     processo seletivo
# 1           Operacoes                outros
# 2  Vendas & Marketing     processo seletivo
# 3  Vendas & Marketing                outros
# 4          Tecnologia                outros
# 5             Analise     processo seletivo
# 6           Operacoes                outros
# 7           Operacoes     processo seletivo
# 8             Analise                outros
# 9  Vendas & Marketing     processo seletivo

# %%
# Acessando todos os dados das colunas X1 e X5
dados.loc[:,["n_de_treinamentos","tempo_de_servico"]]
# Out:
#        n_de_treinamentos  tempo_de_servico
# 0                      1                 8
# 1                      1                 4
# 2                      1                 7
# 3                      2                10
# 4                      1                 2
# ...                  ...               ...
# 54803                  1                17
# 54804                  1                 6
# 54805                  1                 3
# 54806                  1                 2
# 54807                  1                 5
#
# [54808 rows x 2 columns]

# %%
# Acessando um intervalo de dados das colunas X1 até X4
dados.loc[10:20,"departamento":"idade"]
# Out:
#                   departamento     regiao          educacao genero  \
# 10                  Tecnologia  regiao_23               NaN      M
# 11          Vendas & Marketing   regiao_7       Bacharelado      F
# 12          Vendas & Marketing   regiao_4       Bacharelado      M
# 13                  Tecnologia  regiao_29  Mestrado & acima      M
# 14  Pesquisa & Desenvolvimento   regiao_2  Mestrado & acima      M
# 15                   Operacoes   regiao_7       Bacharelado      M
# 16                  Tecnologia   regiao_2       Bacharelado      M
# 17          Vendas & Marketing  regiao_31       Bacharelado      M
# 18          Vendas & Marketing  regiao_31       Bacharelado      M
# 19                   Operacoes  regiao_15       Bacharelado      M
# 20                     Compras  regiao_14       Bacharelado      M
#
#    canal_de_recrutamento  n_de_treinamentos  idade
# 10     processo seletivo                  1     30
# 11     processo seletivo                  1     35
# ...

# %%
# Criando uma mascara com valores maiores ou iguais a 50
dados["idade"] >=50
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 54803    False
# 54804    False
# 54805    False
# 54806    False
# 54807    False
# Name: idade, Length: 54808, dtype: bool

# %%
#Criando uma mascara para valores iguais a Male
dados.canal_de_recrutamento == "Male"
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 54803    False
# 54804    False
# 54805    False
# 54806    False
# 54807    False
# Name: canal_de_recrutamento, Length: 54808, dtype: bool

# %%
# Média, mediana, minimo, máximo e desvio padrão 
media_idade = dados.idade.mean()
mediana_idade = dados.idade.median()
min_idade = dados.idade.min()
max_idade = dados.idade.max()
desvpad_idade = dados.idade.std()

print(f"Média: {media_idade} \nMediana: {mediana_idade}\nMinimo: {min_idade} \nMáximo: {max_idade}\nDesvio padrão: {desvpad_idade}" )
# Out:
# Média: 34.80391548679025
# Mediana: 33.0
# Minimo: 20
# Máximo: 60
# Desvio padrão: 7.660169201585491

# %%
# Resumo dos valores estatisticos
dados.describe()
# Out:
#        id_empregado  n_de_treinamentos         idade  pontuacao_ano_anterior  \
# count  54808.000000       54808.000000  54808.000000            50684.000000
# mean   39195.830627           1.253011     34.803915                3.329256
# std    22586.581449           0.609264      7.660169                1.259993
# min        1.000000           1.000000     20.000000                1.000000
# 25%    19669.750000           1.000000     29.000000                3.000000
# 50%    39225.500000           1.000000     33.000000                3.000000
# 75%    58730.500000           1.000000     39.000000                4.000000
# max    78298.000000          10.000000     60.000000                5.000000
#
#        tempo_de_servico     KPIs >80%  venceu_premiacoes?  \
# count      54808.000000  54808.000000        54808.000000
# mean           5.865512      0.351974            0.023172
# std            4.265094      0.477590            0.150450
# ...

# %%
# Removendo colunas 
dados.drop(columns=["id_empregado","tempo_de_servico"])
# Out:
#              departamento     regiao          educacao genero  \
# 0      Vendas & Marketing   regiao_7  Mestrado & acima      F
# 1               Operacoes  regiao_22       Bacharelado      M
# 2      Vendas & Marketing  regiao_19       Bacharelado      M
# 3      Vendas & Marketing  regiao_23       Bacharelado      M
# 4              Tecnologia  regiao_26       Bacharelado      M
# ...                   ...        ...               ...    ...
# 54803          Tecnologia  regiao_14       Bacharelado      M
# 54804           Operacoes  regiao_27  Mestrado & acima      F
# 54805             Analise   regiao_1       Bacharelado      M
# 54806  Vendas & Marketing   regiao_9               NaN      M
# 54807                  RH  regiao_22       Bacharelado      M
#
#       canal_de_recrutamento  n_de_treinamentos  idade  pontuacao_ano_anterior  \
# 0         processo seletivo                  1     35                     5.0
# ...

# %% [markdown]
# **Relação de dados em cada coluna a fim de identificar padrões e realizar previsões.**

# %%
# Plotando histogramas
dados.hist(figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7efc6b495990>,
# ...
#       dtype=object)

# %%
# Explorarando as possíveis relações
plt.figure(figsize=(20,30))
plt.subplots_adjust(hspace=0.5)
i = 1

colunas_categoricas=["educacao"]

for col_name in dados.columns.drop(colunas_categoricas):
    plt.subplot(4,4,i)
    sns.histplot(data=dados, x=col_name, kde=True, hue='educacao', multiple='layer', alpha=0.5, palette='viridis')
    i += 1

# %%
# Plotadando gráfico com as variáveis categóricas
colunas_categoricas = ["genero", "educacao", "departamento"]
plt.figure(figsize=(40,40))
plt.subplots_adjust(hspace=0.5)
i = 1
for col_name in colunas_categoricas:
    plt.subplot(3,3,i)
    sns.countplot(dados[col_name])
    i += 1
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# Observa-se que nos dados "genero" há um maior percentual Q3(75%) masculino(M) sobre o feminino(F) Q1(25%), isso ocorre também sobre os dados "educação" e "departamento".

# %%
# Explorarando dados categoricos, pelo tamanho
dados.groupby(['departamento']).size()
# Out:
# departamento
# Analise                        5352
# Compras                        7138
# Financeiro                     2536
# Legal                          1039
# Operacoes                     11348
# Pesquisa & Desenvolvimento      999
# RH                             2418
# Tecnologia                     7138
# Vendas & Marketing            16840
# dtype: int64

# %%
#Explorarando dados categoricos, pelo tamanho
dados.groupby(['idade']).size()
# Out:
# idade
# 20     113
# 21      98
# 22     231
# 23     428
# 24     845
# 25    1299
# 26    2060
# 27    2827
# 28    3147
# 29    3405
# 30    3665
# 31    3534
# 32    3534
# 33    3210
# 34    3076
# 35    2711
# 36    2517
# 37    2165
# 38    1923
# 39    1695
# 40    1663
# 41    1289
# 42    1149
# 43     992
# 44     847
# 45     760
# 46     697
# 47     557
# 48     557
# 49     441
# 50     521
# 51     389
# 52     351
# 53     364
# 54     313
# 55     294
# 56     264
# 57     238
# 58     213
# 59     209
# 60     217
# dtype: int64

# %%
# Explorarando dados categoricos, pelo tamanho
dados.groupby(['genero']).size()
# Out:
# genero
# F    16312
# M    38496
# dtype: int64

# %%
sns.pairplot(data = dados, hue = "idade")

# %% [markdown]
# **Outliers com Boxplots ⬇**

# %%
# Verificando a presença de outliers com Boxplots individualmente
sns.boxplot(dados['pontuacao_media_treinamentos']).set_title('pontuacao_media_treinamentos')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, 'pontuacao_media_treinamentos')

# %%
# Verificando a presença de outliers com Boxplots individualmente
sns.boxplot(dados['idade']).set_title('idade')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, 'idade')

# %%
# Verificando a presença de outliers com Boxplots individualmente
sns.boxplot(dados['tempo_de_servico']).set_title('tempo_de_servico')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, 'tempo_de_servico')

# %%
# Verificando a presença de outliers com Boxplots individualmente
sns.boxplot(dados['KPIs >80%']).set_title('KPIs >80%')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, 'KPIs >80%')

# %%
# Verificando a presença de outliers com Boxplots individualmente
sns.boxplot(dados['pontuacao_media_treinamentos']).set_title('pontuacao_media_treinamentos')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, 'pontuacao_media_treinamentos')

# %%
# Outliers com Boxplots / completo
plt.figure(figsize=(20,20))
plt.subplots_adjust(hspace=0.5)
 
colunas_categoricas = ["idade","tempo_de_servico"]
 
i = 1
for col_name in colunas_categoricas:
    plt.subplot(2,2,i)
    sns.boxplot(data=dados,y=col_name)
    i +=1

# %% [markdown]
# Desconsiderando o valor discrepante, é possivél notar nos dados: </br>
# "pontuacao_media_treinamentos": um percentil um pouco abaixo de 50; </br>
# "idade": um percentil abaixo de 50; </br>
# "tempo_de_servico": Q1(25%); </br>
# "KPIs >80%": limite superior Q3+1,5*IQR; </br>
# "pontuacao_media_treinamentos": Q3(75%).

# %%
# Valores nulos
dados.isnull()
# Out:
#        id_empregado  departamento  regiao  educacao  genero  \
# 0             False         False   False     False   False
# 1             False         False   False     False   False
# 2             False         False   False     False   False
# 3             False         False   False     False   False
# 4             False         False   False     False   False
# ...             ...           ...     ...       ...     ...
# 54803         False         False   False     False   False
# 54804         False         False   False     False   False
# 54805         False         False   False     False   False
# 54806         False         False   False      True   False
# 54807         False         False   False     False   False
#
#        canal_de_recrutamento  n_de_treinamentos  idade  \
# 0                      False              False  False
# 1                      False              False  False
# 2                      False              False  False
# ...

# %%
# Contando a quantidade de valores verdadeiros ou falsos das colunas
dados.isnull().sum()
# Out:
# id_empregado                       0
# departamento                       0
# regiao                             0
# educacao                        2409
# genero                             0
# canal_de_recrutamento              0
# n_de_treinamentos                  0
# idade                              0
# pontuacao_ano_anterior          4124
# tempo_de_servico                   0
# KPIs >80%                          0
# venceu_premiacoes?                 0
# pontuacao_media_treinamentos       0
# foi_promovido                      0
# dtype: int64

# %%
# Tratando os valores nulos
dados_drop = dados.dropna()
print ("Dados: ",dados.shape, "|", "Dados sem valores nulos: ",dados_drop.shape)
# Out:
# Dados:  (54808, 14) | Dados sem valores nulos:  (48660, 14)

# %%
#Eliminando os valores nulos
dados.dropna(inplace=True)
print (dados.shape)
# Out:
# (48660, 14)

# %%
# Aplicando o One Hot Enconding
dados_1 = pd.get_dummies(dados["canal_de_recrutamento"], prefix = "canal_de_recrutamento")
dados_1.head()
# Out:
#    canal_de_recrutamento_indicacao  canal_de_recrutamento_outros  \
# 0                                0                             0
# 1                                0                             1
# 2                                0                             0
# 3                                0                             1
# 4                                0                             1
#
#    canal_de_recrutamento_processo seletivo
# 0                                        1
# 1                                        0
# 2                                        1
# 3                                        0
# 4                                        0

# %%
# Concatenando os dados:
dados_corrigidos = pd.concat([dados, dados_1], axis=1)
dados_corrigidos.head()
# Out:
#    id_empregado        departamento     regiao          educacao genero  \
# 0         65438  Vendas & Marketing   regiao_7  Mestrado & acima      F
# 1         65141           Operacoes  regiao_22       Bacharelado      M
# 2          7513  Vendas & Marketing  regiao_19       Bacharelado      M
# 3          2542  Vendas & Marketing  regiao_23       Bacharelado      M
# 4         48945          Tecnologia  regiao_26       Bacharelado      M
#
#   canal_de_recrutamento  n_de_treinamentos  idade  pontuacao_ano_anterior  \
# 0     processo seletivo                  1     35                     5.0
# 1                outros                  1     30                     5.0
# 2     processo seletivo                  1     34                     3.0
# 3                outros                  2     39                     1.0
# 4                outros                  1     45                     3.0
#
#    tempo_de_servico  KPIs >80%  venceu_premiacoes?  \
# ...

# %%
# Vizualizando dados únicos para transformar em valores númericos
regiao_unica = pd.unique(dados.regiao)
print (regiao_unica)
# Out:
# ['regiao_7' 'regiao_22' 'regiao_19' 'regiao_23' 'regiao_26' 'regiao_2'
#  'regiao_20' 'regiao_34' 'regiao_1' 'regiao_4' 'regiao_29' 'regiao_31'
#  'regiao_15' 'regiao_14' 'regiao_11' 'regiao_5' 'regiao_28' 'regiao_17'
#  'regiao_13' 'regiao_16' 'regiao_25' 'regiao_10' 'regiao_27' 'regiao_30'
#  'regiao_12' 'regiao_21' 'regiao_32' 'regiao_6' 'regiao_33' 'regiao_8'
#  'regiao_24' 'regiao_3' 'regiao_9' 'regiao_18']

# %%
# Vizualizando dados únicos para transformar em valores númericos
dep_unica = pd.unique(dados.departamento)
print (dep_unica)
# Out:
# ['Vendas & Marketing' 'Operacoes' 'Tecnologia' 'Analise'
#  'Pesquisa & Desenvolvimento' 'Compras' 'Financeiro' 'RH' 'Legal']

# %%
# Vizualizando dados únicos para transformar em valores númericos
ed_unica = pd.unique(dados.educacao)
print (ed_unica)
# Out:
# ['Mestrado & acima' 'Bacharelado' 'Abaixo do ensino medio']

# %%
# Vizualizando dados únicos para transformar em valores númericos
gen_unica = pd.unique(dados.genero)
print (gen_unica)
# Out:
# ['F' 'M']

# %%
# Vizualizando dados únicos para transformar em valores númericos
canal_unica = pd.unique(dados.canal_de_recrutamento)
print (canal_unica)
# Out:
# ['processo seletivo' 'outros' 'indicacao']

# %%
# Transformando os dados em valores numéricos // Labeling Enconding 

dados_corrigidos['departamento_num'] =  dados_corrigidos['departamento'].replace({'Vendas & Marketing': 0, 
                                                                                  'Tecnologia': 1,
                                                                                  'Analise': 3,
                                                                                  'Pesquisa & Desenvolvimento': 4,
                                                                                  'Compras': 5,
                                                                                  'Financeiro': 6,
                                                                                  'RH': 7,
                                                                                  'Legal': 8,
                                                                                  'Operacoes': 9})
dados_corrigidos['regiao_num'] =  dados_corrigidos['regiao'].replace({'regiao_1': 0, 
                                                                                'regiao_2': 1,
                                                                                'regiao_3': 2,
                                                                                'regiao_4': 3,
                                                                                'regiao_5': 4,
                                                                                'regiao_6': 5,
                                                                                'regiao_7': 6,
                                                                                'regiao_8': 7,
                                                                                'regiao_9': 8,
                                                                                'regiao_10': 9,
                                                                                'regiao_11': 10,
                                                                                'regiao_12': 11,
                                                                                'regiao_13': 12,
                                                                                'regiao_14': 13,
                                                                                'regiao_15': 14,
                                                                                'regiao_16': 15,
                                                                                'regiao_17': 16,
                                                                                'regiao_18': 17,
                                                                                'regiao_19': 18,
                                                                                'regiao_20': 19,
                                                                                'regiao_21': 20,
                                                                                'regiao_22': 21,
                                                                                'regiao_23': 22,
                                                                                'regiao_24': 23,
                                                                                'regiao_25': 24,
                                                                                'regiao_26': 25,
                                                                                'regiao_27': 26,
                                                                                'regiao_28': 27,
                                                                                'regiao_29': 28,
                                                                                'regiao_30': 29,
                                                                                'regiao_31': 30,
                                                                                'regiao_32': 31,
                                                                                'regiao_33': 32,
                                                                                'regiao_34': 33})

dados_corrigidos['educacao_num'] =  dados_corrigidos['educacao'].replace({'Mestrado & acima': 0,
                                                                                'Abaixo do ensino medio': 1,
                                                                                'Bacharelado': 2})
dados_corrigidos['genero_num'] =  dados_corrigidos['genero'].replace({'F': 0,
                                                                      'M' : 1,})

dados_corrigidos.head()
# Out:
#    id_empregado        departamento     regiao          educacao genero  \
# 0         65438  Vendas & Marketing   regiao_7  Mestrado & acima      F
# 1         65141           Operacoes  regiao_22       Bacharelado      M
# 2          7513  Vendas & Marketing  regiao_19       Bacharelado      M
# 3          2542  Vendas & Marketing  regiao_23       Bacharelado      M
# 4         48945          Tecnologia  regiao_26       Bacharelado      M
#
#   canal_de_recrutamento  n_de_treinamentos  idade  pontuacao_ano_anterior  \
# 0     processo seletivo                  1     35                     5.0
# 1                outros                  1     30                     5.0
# 2     processo seletivo                  1     34                     3.0
# 3                outros                  2     39                     1.0
# 4                outros                  1     45                     3.0
#
#    tempo_de_servico  ...  venceu_premiacoes?  pontuacao_media_treinamentos  \
# ...

# %%
# Eliminando colunas categoricas
dados_corrigidos.drop(columns = ["departamento", "regiao","educacao","genero","canal_de_recrutamento"], inplace = True)

# %%
#Verificando colunas com label encoding
dados_corrigidos.head()
# Out:
#    id_empregado  n_de_treinamentos  idade  pontuacao_ano_anterior  \
# 0         65438                  1     35                     5.0
# 1         65141                  1     30                     5.0
# 2          7513                  1     34                     3.0
# 3          2542                  2     39                     1.0
# 4         48945                  1     45                     3.0
#
#    tempo_de_servico  KPIs >80%  venceu_premiacoes?  \
# 0                 8          1                   0
# 1                 4          0                   0
# 2                 7          0                   0
# 3                10          0                   0
# 4                 2          0                   0
#
#    pontuacao_media_treinamentos  foi_promovido  \
# 0                            49              0
# 1                            60              0
# 2                            50              0
# 3                            50              0
# ...

# %%
# Criando uma mascara para selecionar os valores acima de 100 anos menores ou iguais a zero
mascara = (dados_corrigidos["idade"] <=  0 )  | ( dados_corrigidos["idade"] >  100)
mascara
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 54802    False
# 54803    False
# 54804    False
# 54805    False
# 54807    False
# Name: idade, Length: 48660, dtype: bool

# %%
# Correlação de Pearson
plt.figure(figsize=(12,6))
sns.heatmap(dados_corrigidos.corr(), annot=True)

# %% [markdown]
# Com base nos conjuntos de dados é possível fazer uma medida do grau da correlação entre "id_empregado" e "canal_de_recrutamento_processo_seletivo".

# %% [markdown]
# **FEATURES**
#
# id_empregado(int): identificador empregado (unique) </br>
# departamento(obj): departamento (análise, compras, financeiro,legal, operacoes, pesquisa & desenvolvimento, RH, tecnologia, vendas e marketing)</br>
# regiao(obj): tipo de região (deveria ser tipo boolean) </br>
# educacao(obj): escolaridade (mestrado & acima, bacharelado e abaixo do ensino médio) </br>
# genero(obj): Genêro(Male/Female - deveria ser boolean) </br>
# canal_de_recrutamento(obj): meio de recrutamento (processo seletivo,outros) </br>
# n_de_treinamentos(int): número de treinamento </br>
# idade(int): idade </br>
# pontuacao_ano_anterior(float): pontuação do ano anterior </br>
# tempo_de_servico(int): tempo de serviço</br>
# KPIs >80%(int) indicador de performance(deveria ser tipo float ou double):  </br>
# venceu_premiacoes?(int): venceu premiações(deveria ser boolean) </br>
# pontuacao_media_treinamentos(int) pontuação(deveria ser tipo float ou double)</br>
# foi_promovido(int) promovido(deveria ser tipo boolean)</br>

# %% [markdown]
# **Conclusão da Análise**
#
# A realização desta análise exploratória se deu através das seguintes bibliotecas: pandas, seaborn e matplotlib, onde extraímos os elementos disponibilizado no arquivo dados_rh.csv.</br>
#
# Ao analisar todos os gráficos apresentados observa-se que a maior parte que estão passando por processos seletivos são homens com percentual de 75%,já as mulheres é bem baixo com 25%, sendo em sua maioria com bacharelado, seguido de mestrado & acima, o nível mais inferior são de pessoas abaixo do ensino médio.</br>
# As áreas com adesão de processo seletivo está entre as vagas de Operrações, Vendas & Marketing e Tecnologia. Grande parte desses candidatos tem no minímo um treinamento com idade entre 30 a 45 anos com pontuação acima de 1.0.</br>
# Conlui-se que dentro das áreas apresentadas a média de pessoas que tem a maior probalidade de passar pelo processo são homens de idade média de 30 anos, com mais de 2 anos de tempo de serviço e com indicador de performance acima de 1,5.
