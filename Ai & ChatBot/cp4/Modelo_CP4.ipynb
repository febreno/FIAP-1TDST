# %% [markdown]
# **CP4- Inteligência Artificial e Computacional**
#
# Analise Exploratória dos Dados
#
# Nomes:
#
# [Colocar nome e RM dos integrantes do grupo]

# %% [markdown]
# *Orientações:*
#
# - Em grupos do Challenge
#
# - Esse arquivo contem o modelo esperado de respostas para a CP3. Podem ser acrescentadas algumas outras informações ou trechos com códigos, entretanto não esqueçam de responder todos os pontos que foram levantados a seguir.
#
# - Vocês estão recebendo um arquivo chamado "dados_nac_1.csv". Esse arquivo deve ser usado para carregar os dados no notebbok e realizar a atividade
#
# - Os dados para essa atividade estão disponíveis em: https://www.kaggle.com/ninzaami/loan-predication (Para mais informações sobre os atributos basta acessar o link disponibilizado)

# %% [markdown]
# ## Exercícico 1

# %% [markdown]
# Carregar as bibliotecas necessárias a seguir:

# %%
# Suas bibliotecas aqui

# %% [markdown]
# 1. Carregar os dataset do exercício:

# %%
# Seu Código Aqui

# %% [markdown]
# 2. Fazer a análise exploratória e tratamento dos dados
#
# (Espera-se no minimo que seja verificado os tipos de dados envolvidos e suas médias, desvios padrões e distribuição dos dados, que seja realizado o tratamento dos dados para prepará-los para o uso de Machine Learning, que sejam plotados alguns gráficos para que seja realizada uma análise exploratória dos dados a partir desses plots)

# %%
# Seu Código Aqui

# %% [markdown]
# [OBRIGATÓRIO: COLOCAR ALGUMAS CONCLUSÕES A PARTIR DAS ANALISES DOS GRÁFICOS E OUTROS]

# %% [markdown]
# OBRIGATÓRIO: Explicar quais features estão envolvidas
#
# [Sua resposta aqui]
